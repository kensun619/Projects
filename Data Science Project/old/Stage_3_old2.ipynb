# %%
import sys
import os
import py_entitymatching as em
print('magellan version:' + em.__version__)
import re
import csv
import pandas as pd

from cleaner import Cleaner
from constants import csv_headers
# Out:
# magellan version:0.1.0

# %%
working_dir = os.path.dirname(os.getcwd())
path_to_csv_dir = working_dir + os.sep + 'csv_files'+ os.sep

# %% [markdown]
# # STEP 1 - PRE-PROCESSING DATA
#
# In this stage, we need to preprocess data before applying Megellan. This is because our datasets (especially the AOM dataset) are quite dirty, and therefore adversely affecting Megellan's blocking and matching functions. For example, states can take any value of "CA", "California", or "CA - California".
#
# In this step, we will clean the following variables:
# * Country name (e.g. Whed data has 2 Belgiums: (1) Belgium - French Community and (2) Belgium - Flemish Community)
# * State name
# * City name
# * Affiliation name
# * Email server domain (we will only capture the university information from the email server domain - if there is any)

# %% [markdown]
# ### 1.A. Clean AOM data

# %%
aom_cleaner = Cleaner(path_to_csv_dir + '_aom.csv', csv_headers.AOM_INDEX, csv_headers.AOM)

aom_cleaner.clean_affiliation('a_name')
aom_cleaner.clean_email_server('a_email_server')
aom_cleaner.clean_city('a_city')
aom_cleaner.clean_country('a_country')
aom_cleaner.clean_states('a_prov', 'a_country')

aom_cleaner.to_csv(path_to_csv_dir + '_aom_cleaned.csv')
aom_cleaner.data.head(n=3)
# Out:
#                             a_name            a_city         a_prov  \
# person_id
# 1               academy management  briarcliff manor       new york
# 4          northeastern university            boston  massachusetts
# 5                 skidmore college  saratoga springs       new york
#
#                a_country a_email_server
# person_id
# 1          united states            aom
# 4          united states          gmail
# 5          united states       skidmore

# %% [markdown]
# ### 1.B. Clean WHED data

# %%
whed_cleaner = Cleaner(path_to_csv_dir + '_whed.csv', csv_headers.WHED_INDEX, csv_headers.WHED, encoding = 'ISO-8859-1')

whed_cleaner.clean_affiliation('a_name')
whed_cleaner.clean_city('a_city')
whed_cleaner.clean_country('a_country')
whed_cleaner.clean_states('a_prov', 'a_country')

whed_cleaner.to_csv(path_to_csv_dir + '_whed_cleaned.csv')
whed_cleaner.data.head(n=3)
# Out:
#                                                 a_name    a_country  \
# a_id
# 2               pampanga state agricultural university  philippines
# 4     les roches international school hotel management  switzerland
# 6             dharma gate budapest buddhist university      hungary
#
#                     a_city                a_prov                     a_web
# a_id
# 2                 magalang              pampanga     http://www.pac.edu.ph
# 4     bluche crans montana  bluche-crans-montana  http://www.lesroches.edu
# 6                 budapest                              http://www.tkbf.eu

# %% [markdown]
# # STEP 2 - MAGELLAN - BLOCKING

# %%
AOM = em.read_csv_metadata(path_to_csv_dir + '_aom_cleaned.csv', key = csv_headers.AOM_INDEX)
print(em.get_key(AOM))

WHED = em.read_csv_metadata(path_to_csv_dir + '_whed_cleaned.csv', key = csv_headers.WHED_INDEX)
print(em.get_key(WHED))
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# person_id
# a_id

# %%
# building inverted index based on B
sample_WHED, sample_AOM = em.down_sample(WHED, AOM, size=4000, y_param=1)
print(len(sample_WHED))
print(len(sample_AOM))
em.show_properties(sample_WHED)
em.show_properties(sample_AOM)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:16 | ETA: 00:00:16 | ETA: 00:00:17 | ETA: 00:00:17 | ETA: 00:00:17 | ETA: 00:00:16 | ETA: 00:00:15 | ETA: 00:00:15 | ETA: 00:00:14 | ETA: 00:00:13 | ETA: 00:00:13 | ETA: 00:00:12 | ETA: 00:00:11 | ETA: 00:00:10 | ETA: 00:00:10 | ETA: 00:00:09 | ETA: 00:00:08 | ETA: 00:00:08 | ETA: 00:00:07 | ETA: 00:00:06 | ETA: 00:00:06 | ETA: 00:00:05 | ETA: 00:00:04 | ETA: 00:00:04 | ETA: 00:00:03 | ETA: 00:00:02 | ETA: 00:00:02 | ETA: 00:00:01 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00
# 11230
# 3000
# id: 4619571440
# key: a_id
# id: 4619571328
# key: person_id
# Total time elapsed: 00:00:19

# %%
sample_WHED.head(n=5)
# Out:
#    a_id                                            a_name      a_country  \
# 0     2            pampanga state agricultural university    philippines
# 1     4  les roches international school hotel management    switzerland
# 3     7                    a d patel institute technology          india
# 4     8                              a t still university  united states
# 5     9                                aalborg university        denmark
#
#                  a_city                a_prov                     a_web
# 0              magalang              pampanga     http://www.pac.edu.ph
# 1  bluche crans montana  bluche-crans-montana  http://www.lesroches.edu
# 3    vitthal udyognagar               gujarat     http://www.adit.ac.in
# 4            kirksville              missouri       http://www.atsu.edu
# 5               aalborg                   NaN         http://www.aau.dk

# %%
sample_AOM.head(n=5)
# Out:
#       person_id                                                a_name  \
# 6602      49428                                   university arkansas
# 7643      56071  louisiana state university e j ourso school business
# 8378      57585                                     university passau
# 7104      52879                                   ebs business school
# 6556      49074                                            lmu munich
#
#                a_city     a_prov      a_country a_email_server
# 6602     fayetteville   arkansas  united states           uark
# 7643      baton rouge  louisiana  united states          gmail
# 8378           passau    bavaria        germany     uni-passau
# 7104  oestrich winkel      hesse        germany            ebs
# 6556           munich    bavaria        germany            lmu

# %%
def match_country(ltuple, rtuple):
    l_country = ltuple['a_country']
    r_country = rtuple['a_country']
    if (l_country == "") or (r_country == ""):
        return None
    else:
        return ( l_country == r_country)

def match_country_us(ltuple, rtuple):
    return (rtuple['a_country'] == "united states")

def match_prov(ltuple, rtuple):
    l_prov = ltuple['a_prov']
    r_prov = rtuple['a_prov']
    if (l_prov == "") or (r_prov == ""):
        return None
    else:
        return (l_prov == r_prov)

def match_city(ltuple, rtuple):
    l_city = ltuple['a_city']
    r_city = rtuple['a_city']
    if (l_city  == "") or (r_city == ""):
        return None
    else:
        return (l_city == r_city)

def match_provcity(ltuple, rtuple):
    l_city = ltuple['a_city']
    r_city = rtuple['a_city']
    l_prov = ltuple['a_prov']
    r_prov = rtuple['a_prov']
    if (l_city  == "") or (r_city == "") or (l_prov == "") or (r_prov == ""):
        return None
    else:
        return (str(l_city) == str(r_prov)) or (str(l_prov) == str(r_city))

def match_domain(ltuple, rtuple):
    l_web = str(ltuple['a_web'])
    r_email = str(rtuple['a_email_server'])
    if (l_web == "") or (r_email == ""):
        return None
    else:
        l_web = l_web.split('.')
        return (r_email in l_web)

def match_overlap(ltuple, rtuple):
    l_name = str(ltuple['a_name'])
    r_name = str(rtuple['a_name'])
    
    if (l_name == "") or (r_name == ""):
        return None
    else:
        if l_name.count(" ") > 0 and r_name.count(" ") > 0:
            l_name = re.sub(r"(university|school|institute|college)","",l_name)
            r_name = re.sub(r"(university|school|institute|college)","",r_name)    
            l_tokens = em.tok_wspace(l_name)
            r_tokens = em.tok_wspace(r_name)
            return em.overlap_coeff(l_tokens, r_tokens) > 0.5
        else:
            return None
    
def allFalse(array):
    num_none = array.count(None)
    num_false = array.count(False)    
    return (num_none + num_false) == len(array) and num_none != len(array)
        
    
def match_combined(ltuple, rtuple):
    if match_country(ltuple, rtuple) is False:
        return True
    elif (match_country_us(ltuple,rtuple) is True) and (match_prov(ltuple,rtuple) is False):
        return True
    elif (match_country_us(ltuple,rtuple) is True) and (allFalse([match_overlap(ltuple, rtuple), 
                                                                   match_domain(ltuple, rtuple)]) is True):
        return True
    elif (match_country_us(ltuple,rtuple) is False) and allFalse([match_overlap(ltuple, rtuple), 
                                                                   match_domain(ltuple, rtuple)]) is True:
        return True
    else:
        return False
    
def blocking(A, B):
    bb = em.BlackBoxBlocker()
    bb.set_black_box_function(match_combined)
    C = bb.block_tables(A, B, l_output_attrs=['a_name','a_country','a_city','a_prov','a_web'], r_output_attrs=['a_name','a_country','a_city','a_prov','a_email_server'] )
    return C

C = blocking(sample_WHED, sample_AOM)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:13:56 | ETA: 00:14:00 | ETA: 00:13:54 | ETA: 00:13:45 | ETA: 00:13:14 | ETA: 00:12:33 | ETA: 00:12:02 | ETA: 00:11:36 | ETA: 00:11:04 | ETA: 00:10:23 | ETA: 00:09:50 | ETA: 00:09:18 | ETA: 00:08:47 | ETA: 00:08:15 | ETA: 00:07:47 | ETA: 00:07:15 | ETA: 00:06:44 | ETA: 00:06:12 | ETA: 00:05:43 | ETA: 00:05:14 | ETA: 00:04:40 | ETA: 00:04:07 | ETA: 00:03:37 | ETA: 00:03:05 | ETA: 00:02:34 | ETA: 00:02:04 | ETA: 00:01:33 | ETA: 00:01:02 | ETA: 00:00:31 | ETA: 00:00:00 | ETA: 00:00:00
# Total time elapsed: 00:15:32

# %%
C.size
# Out:
# 132210

# %%
C.head(n=1000)
# Out:
#      _id  ltable_a_id  rtable_person_id  \
# 0      0            9             54111
# 1      1           10              1239
# 2      2           10             58343
# 3      3           10             56765
# 4      4           10              6105
# 5      5           10             39136
# 6      6           10             47260
# 7      7           10             29724
# 8      8           10             54387
# 9      9           10             36779
# 10    10           10             36477
# 11    11           10             59274
# 12    12           10              9363
# 13    13           10             54470
# 14    14           10             58547
# 15    15           10             56107
# 16    16           10             36067
# 996                                               eastern connecticut state university
# 997                                                        eastern illinois university
# 998                                                        eastern illinois university
# 999                                                        eastern illinois university
#
#     ltable_a_country     ltable_a_city ltable_a_prov  \
# 0            denmark           aalborg           NaN
# 1            finland             espoo           NaN
# 2            finland             espoo           NaN
# 3            finland             espoo           NaN
# 4            finland             espoo           NaN
# 5            finland             espoo           NaN
# 6            finland             espoo           NaN
# 7            finland             espoo           NaN
# 8            finland             espoo           NaN
# 9            finland             espoo           NaN
# 10           finland             espoo           NaN
# 11           finland             espoo           NaN
# 12           finland             espoo           NaN
# 13           finland             espoo           NaN
# 14           finland             espoo           NaN
# 15           finland             espoo           NaN
# 16           finland             espoo           NaN
# 17           finland             espoo           NaN
# 18           finland             espoo           NaN
# 19           finland             espoo           NaN
# 20           denmark            aarhus             c
# 21           denmark            aarhus             c
# 22           denmark            aarhus             c
# 23           denmark            aarhus             c
# 24           denmark            aarhus             c
# 25           denmark            aarhus             c
# 26           denmark            aarhus             c
# 27     united states           abilene         texas
# 28           belgium         bruxelles           NaN
# 29           belgium         bruxelles           NaN
# ..               ...               ...           ...
# 970    united states  east stroudsburg  pennsylvania
# 971    united states  east stroudsburg  pennsylvania
# 972    united states  east stroudsburg  pennsylvania
# 973    united states  east stroudsburg  pennsylvania
# 974    united states  east stroudsburg  pennsylvania
# 975    united states  east stroudsburg  pennsylvania
# 976    united states  east stroudsburg  pennsylvania
# 977    united states  east stroudsburg  pennsylvania
# 978    united states  east stroudsburg  pennsylvania
# 979    united states  east stroudsburg  pennsylvania
# 980    united states  east stroudsburg  pennsylvania
# 981    united states  east stroudsburg  pennsylvania
# 982    united states  east stroudsburg  pennsylvania
# 983    united states      johnson city     tennessee
# 984    united states      johnson city     tennessee
# 985    united states      johnson city     tennessee
# 986    united states      johnson city     tennessee
# 987       bangladesh             dhaka           NaN
# 988    united states       willimantic   connecticut
# 989    united states       willimantic   connecticut
# 990    united states       willimantic   connecticut
# 991    united states       willimantic   connecticut
# 992    united states       willimantic   connecticut
# 993    united states       willimantic   connecticut
# 994    united states       willimantic   connecticut
# 995    united states       willimantic   connecticut
# 996    united states       willimantic   connecticut
# 997    united states        charleston      illinois
# 998    united states        charleston      illinois
# 999    united states        charleston      illinois
#
#                  ltable_a_web                          rtable_a_name  \
# 0           http://www.aau.dk                     aalborg university
# 1     http://www.aalto.fi/fi/                       aalto university
# 2     http://www.aalto.fi/fi/                       aalto university
# 3     http://www.aalto.fi/fi/                       aalto university
# 4     http://www.aalto.fi/fi/                       aalto university
# 5     http://www.aalto.fi/fi/                       aalto university
# 6     http://www.aalto.fi/fi/                       aalto university
# 7     http://www.aalto.fi/fi/                       aalto university
# 8     http://www.aalto.fi/fi/                       aalto university
# 9     http://www.aalto.fi/fi/                       aalto university
# 10    http://www.aalto.fi/fi/                       aalto university
# 11    http://www.aalto.fi/fi/                       aalto university
# 16           finland          helsinki           NaN                 aalto
# 17           finland          helsinki           NaN                 aalto
# 18           finland             aalto             -                 aalto
# 19           finland          helsinki           NaN                 aalto
# 20           denmark            aarhus           NaN                   asb
# 21           denmark            aarhus           NaN                   asb
# 22           denmark            aarhus          8000                   asb
# 23           denmark            aarhus           NaN                    au
# 24           denmark            aarhus           NaN                   asb
# 25           denmark            aarhus           NaN                   asb
# 26           denmark            aarhus           NaN                   asb
# 27     united states           abilene         texas                   acu
# 28           belgium          brussels           NaN                   ulb
# 29           belgium         bruxelles           NaN                   ulb
# ..               ...               ...           ...                   ...
# 970    united states      philadelphia  pennsylvania                 upenn
# 971    united states      philadelphia  pennsylvania                 upenn
# 972    united states      philadelphia  pennsylvania                 upenn
# 973    united states      philadelphia  pennsylvania                 upenn
# 974    united states      philadelphia  pennsylvania                 upenn
# 975    united states      philadelphia  pennsylvania                 upenn
# 976    united states      philadelphia  pennsylvania                 upenn
# 977    united states      philadelphia  pennsylvania                 upenn
# 978    united states      philadelphia  pennsylvania                 upenn
# 979    united states      philadelphia  pennsylvania                 upenn
# 980    united states      philadelphia  pennsylvania                 upenn
# 981    united states      philadelphia  pennsylvania                 upenn
# 982    united states      philadelphia  pennsylvania                 upenn
# 983    united states      murfreesboro     tennessee                  mtsu
# 984    united states      johnson city     tennessee                  etsu
# 985    united states         knoxville     tennessee                   utk
# 986    united states      johnson city     tennessee                  etsu
# 987       bangladesh             dhaka           NaN                 gmail
# 988    united states           danbury   connecticut                  wcsu
# 989    united states            storrs   connecticut                 uconn
# 990    united states       east haddam   connecticut            southernct
# 991    united states            storrs   connecticut                 uconn
# 992    united states  storrs mansfield   connecticut                 uconn
# 993    united states            storrs   connecticut                 uconn
# 994    united states       new britain   connecticut                  ccsu
# 995    united states            storrs   connecticut                 uconn
# 996    united states            storrs   connecticut                 uconn
# 997    united states         champaign      illinois              illinois
# 998    united states         champaign      illinois              illinois
# 999    united states         champaign      illinois                  ucsf
#
# [1000 rows x 13 columns]

# %%
em.to_csv_metadata(C, path_to_csv_dir + 'matching_pairs_table_overlap2_emailserver.csv')
em.save_table(C, path_to_csv_dir + 'matching_pairs_table_overlap2_emailserver.pkl')
# Out:
# File already exists at /Users/thomasngo/Google Drive/_UW Madison/16-17_S4/CS 838/_Project/git_code/cs838-spring2017/stage3/csv_files/matching_pairs_table_overlap2_emailserver.pkl; Overwriting it
# Metadata file already exists at /Users/thomasngo/Google Drive/_UW Madison/16-17_S4/CS 838/_Project/git_code/cs838-spring2017/stage3/csv_files/matching_pairs_table_overlap2_emailserver.pklmetadata. Overwriting it
# True

# %%
sample_AOM.to_csv(path_to_csv_dir + 'sample_AOM.csv', encoding = 'UTF-8', index_label = csv_headers.AOM_INDEX)
sample_WHED.to_csv(path_to_csv_dir + 'sample_WHED.csv', encoding = 'UTF-8', index_label = csv_headers.WHED_INDEX)
