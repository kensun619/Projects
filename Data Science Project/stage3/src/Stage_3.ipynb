# %%
import sys
import os
import py_entitymatching as em
print('magellan version:' + em.__version__)
import re
import csv
import pandas as pd

from cleaner import Cleaner
from constants import csv_headers
import blocker, custom_matcher
# Out:
# magellan version:0.1.0
# /Users/Ken/anaconda/lib/python3.5/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
working_dir = os.path.dirname(os.getcwd())
path_to_csv_dir = working_dir + os.sep + 'csv_files'+ os.sep

# %% [markdown]
# # STEP 1 - PRE-PROCESSING DATA
#
# In this stage, we need to preprocess data before applying Megellan. This is because our datasets (especially the AOM dataset) are quite dirty, and therefore adversely affecting Megellan's blocking and matching functions. For example, states can take any value of "CA", "California", or "CA - California".
#
# In this step, we will clean the following variables:
# * Country name (e.g. Whed data has 2 Belgiums: (1) Belgium - French Community and (2) Belgium - Flemish Community)
# * State name
# * City name
# * Affiliation name
# * Email server domain (we will only capture the university information from the email server domain - if there is any)

# %% [markdown]
# ### 1.A. Clean AOM data

# %%
aom_cleaner = Cleaner(path_to_csv_dir + '_aom.csv', csv_headers.AOM_INDEX, csv_headers.AOM)

aom_cleaner.clean_affiliation('a_name')
aom_cleaner.clean_email_server('a_email_server')
aom_cleaner.clean_city('a_city')
aom_cleaner.clean_country('a_country')
aom_cleaner.clean_states('a_prov', 'a_country')

aom_cleaner.to_csv(path_to_csv_dir + '_aom_cleaned.csv')
aom_cleaner.data.head(n=3)
# Out:
#                             a_name            a_city         a_prov  \
# person_id
# 1               academy management  briarcliff manor       new york
# 4          northeastern university            boston  massachusetts
# 5                 skidmore college  saratoga springs       new york
#
#                a_country a_email_server a_email_server_cleaned
# person_id
# 1          united states        aom.org                    aom
# 4          united states      gmail.com                  gmail
# 5          united states   skidmore.edu               skidmore

# %% [markdown]
# ### 1.B. Clean WHED data

# %%
whed_cleaner = Cleaner(path_to_csv_dir + '_whed.csv', csv_headers.WHED_INDEX, csv_headers.WHED, encoding = 'ISO-8859-1')

whed_cleaner.clean_affiliation('a_name')
whed_cleaner.clean_city('a_city')
whed_cleaner.clean_country('a_country')
whed_cleaner.clean_states('a_prov', 'a_country')

whed_cleaner.to_csv(path_to_csv_dir + '_whed_cleaned.csv')
whed_cleaner.data.head(n=3)
# Out:
#                                                 a_name    a_country  \
# a_id
# 2               pampanga state agricultural university  philippines
# 4     les roches international school hotel management  switzerland
# 6             dharma gate budapest buddhist university      hungary
#
#                     a_city                a_prov                     a_web
# a_id
# 2                 magalang              pampanga     http://www.pac.edu.ph
# 4     bluche crans montana  bluche-crans-montana  http://www.lesroches.edu
# 6                 budapest                              http://www.tkbf.eu

# %% [markdown]
# # STEP 2 - MAGELLAN - BLOCKING

# %%
AOM = em.read_csv_metadata(path_to_csv_dir + '_aom_cleaned.csv', key = csv_headers.AOM_INDEX)
WHED = em.read_csv_metadata(path_to_csv_dir + '_whed_cleaned.csv', key = csv_headers.WHED_INDEX)

# building inverted index based on B
sample_WHED, sample_AOM = em.down_sample(WHED, AOM, size=4000, y_param=3)
print(len(sample_WHED))
print(len(sample_AOM))
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file
# 11    11           10             24930
# 12    12           10             10509
# 13    13           10             58872
# 14    14           10             29248
# 15    15           10             54397
# 16    16           10             55949
# 17    17           10             52765
# 18    18           10             48778
# 19    19           10             36067
# 20    20           15             19726
# 21    21           15             58875
# 22    22           15             33098
# 23    23           15             30503
# 24    24           15             57262
# 25    25           15              2773
# 26    26        11560             20219
# 27    27        11558             52081
# 28    28        11558              4464
# 29    29        21864             57157
# ..   ...          ...               ...
# 970  970        12769               870
# 971  971        12769             44587
# 972  972        12769             43489
# 973  973        12769             20201
# 974  974        12769             49163
# 975  975        12769             14691
# 976  976        12769             29877
# 977  977        12769             10892
# 978  978        12769             27581
# 979  979        12769             43816
# 980  980        12769             35303
# 981  981        12769              3996
# 982  982        12769             13990
# 983  983        12769              8628
# 984  984        12769             34165
# 985  985        12769             43520
# 986  986        12769             20567
# 987  987        12769              2525
# 988  988        12769             21999
# 989  989        12769              5325
# 990  990        12769             47643
# 991  991        12769              3225
# 992  992        12769             37841
# 993  993        12769             51257
# 994  994        12770             55141
# 995  995        12770              6881
# 996  996        12770             50912
# 997  997        12770             55758
# 998  998        12770               230
# 999  999        12770             41200
#
#                                           ltable_a_name ltable_a_country  \
# 0                                      aalto university          finland
# 1                                      aalto university          finland
# 2                                      aalto university          finland
# 3                                      aalto university          finland
# 4                                      aalto university          finland
# 5                                      aalto university          finland
# 6                                      aalto university          finland
# 7                                      aalto university          finland
# 8                                      aalto university          finland
# 9                                      aalto university          finland
# 10                                     aalto university          finland
# 11                                     aalto university          finland
# 12                                     aalto university          finland
# 13                                     aalto university          finland
# 14                                     aalto university          finland
# 15                                     aalto university          finland
# 16                                     aalto university          finland
# 17                                     aalto university          finland
# 18                                     aalto university          finland
# 19                                     aalto university          finland
# 20                                    aarhus university          denmark
# 21                                    aarhus university          denmark
# 22                                    aarhus university          denmark
# 23                                    aarhus university          denmark
# 24                                    aarhus university          denmark
# 25                                    aarhus university          denmark
# 26                               mendel university brno   czech republic
# 27                     memorial university newfoundland           canada
# 28                     memorial university newfoundland           canada
# 29   university applied sciences zurcher fachhochschule      switzerland
# ..                                                  ...              ...
# 970                   north carolina central university    united states
# 971                   north carolina central university    united states
# 972                   north carolina central university    united states
# 973                   north carolina central university    united states
# 974                   north carolina central university    united states
# 975                   north carolina central university    united states
# 976                   north carolina central university    united states
# 977                   north carolina central university    united states
# 978                   north carolina central university    united states
# 979                   north carolina central university    united states
# 980                   north carolina central university    united states
# 981                   north carolina central university    united states
# 982                   north carolina central university    united states
# 983                   north carolina central university    united states
# 984                   north carolina central university    united states
# 985                   north carolina central university    united states
# 986                   north carolina central university    united states
# 987                   north carolina central university    united states
# 988                   north carolina central university    united states
# 989                   north carolina central university    united states
# 990                   north carolina central university    united states
# 991                   north carolina central university    united states
# 992                   north carolina central university    united states
# 993                   north carolina central university    united states
# 994                     north carolina state university    united states
# 995                     north carolina state university    united states
# 996                     north carolina state university    united states
# 997                     north carolina state university    united states
# 998                     north carolina state university    united states
# 999                     north carolina state university    united states
#
#                              rtable_a_name rtable_a_country rtable_a_city  \
# 0                         aalto university          finland         aalto
# 1                         aalto university          finland      helsinki
# 2                         aalto university          finland         espoo
# 3                         aalto university          finland      helsinki
# 4                         aalto university          finland         espoo
# 5                         aalto university          finland         aalto
# 6                         aalto university          finland         aalto
# 7                         aalto university          finland         espoo
# 8                         aalto university          finland      helsinki
# 9                         aalto university          finland         espoo
# 10                        aalto university          finland      helsinki
# 11                        aalto university          finland      helsinki
# 12                        aalto university          finland      helsinki
# 13                        aalto university          finland      helsinki
# 14                        aalto university          finland         aalto
# 15                        aalto university          finland      helsinki
# 16                        aalto university          finland      helsinki
# 17                        aalto university          finland         espoo
# 18                        aalto university          finland      helsinki
# 19                        aalto university          finland      helsinki
# 20                       aarhus university          denmark        aarhus
# 21                       aarhus university          denmark        aarhus
# 22                       aarhus university          denmark        aarhus
# 23                       aarhus university          denmark        aarhus
# 24                       aarhus university          denmark        aarhus
# 25                       aarhus university          denmark        aarhus
# 26                       mendel university   czech republic          brno
# 27        memorial university newfoundland           canada    st. john s
# 28        memorial university newfoundland           canada    st. john s
# 29      zurich university applied sciences      switzerland    winterthur
# ..                                     ...              ...           ...
# 970        north carolina state university    united states       raleigh
# 971  university north carolina chapel hill    united states   chapel hill
# 972    university north carolina charlotte    united states     charlotte
# 973              university north carolina    united states   chapel hill
# 974    university north carolina charlotte    united states     charlotte
# 975              university north carolina    united states   chapel hill
# 976   university north carolina greensboro    united states    greensboro
# 977  university north carolina chapel hill    united states   chapel hill
# 978  university north carolina chapel hill    united states   chapel hill
# 979    university north carolina charlotte    united states     charlotte
# 980  university north carolina chapel hill    united states   chapel hill
# 981              university north carolina    united states   chapel hill
# 982  university north carolina chapel hill    united states   chapel hill
# 983    north carolina a t state university    united states    greensboro
# 984              university north carolina    united states   chapel hill
# 985  university north carolina chapel hill    united states   chapel hill
# 986    university north carolina charlotte    united states     charlotte
# 987    north carolina a t state university    united states    greensboro
# 988              university north carolina    united states    greensboro
# 989   university north carolina greensboro    united states    greensboro
# 990   university north carolina greensboro    united states    greensboro
# 991        north carolina state university    united states       raleigh
# 992  university north carolina chapel hill    united states     pittsboro
# 993  university north carolina chapel hill    united states   chapel hill
# 994  university north carolina chapel hill    united states   chapel hill
# 995  university north carolina chapel hill    united states   chapel hill
# 996    university north carolina charlotte    united states     charlotte
# 997  university north carolina chapel hill    united states   chapel hill
# 998    university north carolina charlotte    united states     charlotte
# 999  university north carolina chapel hill    united states   chapel hill
#
#       rtable_a_prov  rtable_a_email_server
# 0               NaN             aaltoee.fi
# 1               NaN               aalto.fi
# 2               NaN               aalto.fi
# 3               NaN               aalto.fi
# 4               NaN               aalto.fi
# 5               NaN               aalto.fi
# 6               NaN                 tkk.fi
# 7               NaN               aalto.fi
# 8          helsinki               aalto.fi
# 9               NaN               aalto.fi
# 10          uusimaa               aalto.fi
# 11              NaN               aalto.fi
# 12              NaN               aalto.fi
# 13              NaN               aalto.fi
# 14                -               aalto.fi
# 15         helsinki               aalto.fi
# 16              NaN               aalto.fi
# 17          finland               aalto.fi
# 18              NaN               aalto.fi
# 19              NaN               aalto.fi
# 20              NaN                 asb.dk
# 21              NaN              hum.au.dk
# 22          danmark                 asb.dk
# 23          danmark                 asb.dk
# 24              NaN                 asb.dk
# 25              NaN                 asb.dk
# 26              NaN              gmail.com
# 27               nl                 mun.ca
# 28               nl                 mun.ca
# 29              NaN                zhaw.ch
# ..              ...                    ...
# 970  north carolina               ncsu.edu
# 971  north carolina                unc.edu
# 972  north carolina               uncc.edu
# 973  north carolina              gmail.com
# 974  north carolina               uncc.edu
# 975  north carolina                unc.edu
# 976  north carolina              gmail.com
# 977  north carolina  kenan-flagler.unc.edu
# 978  north carolina                unc.edu
# 979  north carolina               uncc.edu
# 980  north carolina                unc.edu
# 981  north carolina                unc.edu
# 982  north carolina                unc.edu
# 983  north carolina               ncat.edu
# 984  north carolina                unc.edu
# 985  north carolina                unc.edu
# 986  north carolina               uncc.edu
# 987  north carolina               ncat.edu
# 988  north carolina               uncg.edu
# 989  north carolina               uncg.edu
# 990  north carolina               uncg.edu
# 991  north carolina               ncsu.edu
# 992  north carolina          email.unc.edu
# 993  north carolina  kenan-flagler.unc.edu
# 994  north carolina           live.unc.edu
# 995  north carolina                unc.edu
# 996  north carolina               uncc.edu
# 997  north carolina              gmail.com
# 998  north carolina               uncc.edu
# 999  north carolina                unc.edu
#
# [1000 rows x 13 columns]

# %%
em.to_csv_metadata(C, path_to_csv_dir + 'matching_pairs_table_overlap3_emailserver.csv')
em.save_table(C, path_to_csv_dir + 'matching_pairs_table_overlap3_emailserver.pkl')

sample_AOM.to_csv(path_to_csv_dir + 'sample_AOM.csv', encoding = 'UTF-8', index_label = csv_headers.AOM_INDEX)
sample_WHED.to_csv(path_to_csv_dir + 'sample_WHED.csv', encoding = 'UTF-8', index_label = csv_headers.WHED_INDEX)
# Out:
# File already exists at /Users/carepjan/code/website/stage3/csv_files/matching_pairs_table_overlap3_emailserver.csv; Overwriting it
# Metadata file already exists at /Users/carepjan/code/website/stage3/csv_files/matching_pairs_table_overlap3_emailserver.metadata. Overwriting it
# File already exists at /Users/carepjan/code/website/stage3/csv_files/matching_pairs_table_overlap3_emailserver.pkl; Overwriting it
# Metadata file already exists at /Users/carepjan/code/website/stage3/csv_files/matching_pairs_table_overlap3_emailserver.pklmetadata. Overwriting it

# %% [markdown]
# # STEP 3 - MAGELLAN - MATCHING

# %%
# Load data
AOM = em.read_csv_metadata(path_to_csv_dir + '_aom.csv', key = csv_headers.AOM_INDEX)
WHED = em.read_csv_metadata(path_to_csv_dir + '_whed.csv', key = csv_headers.WHED_INDEX)
labeled_data = em.read_csv_metadata(path_to_csv_dir + 'golden_data_labeled_nomissing.csv', key='_id',
                                                                 ltable=WHED, rtable=AOM, 
                                                                 fk_ltable='ltable_' + csv_headers.WHED_INDEX, 
                                                                 fk_rtable='rtable_' + csv_headers.AOM_INDEX,encoding = "ISO-8859-1")

# Split train and test set
IJ = em.split_train_test(labeled_data, train_proportion=0.5, random_state=0)
I = IJ['train']
J = IJ['test']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-181ef24e10b5> in <module>()
#       1 # Load data
# ----> 2 AOM = em.read_csv_metadata(path_to_csv_dir + '_aom.csv', key = csv_headers.AOM_INDEX)
#       3 WHED = em.read_csv_metadata(path_to_csv_dir + '_whed.csv', key = csv_headers.WHED_INDEX)
#       4 labeled_data = em.read_csv_metadata(path_to_csv_dir + 'golden_data_labeled_nomissing.csv', key='_id',
#       5                                                                  ltable=WHED, rtable=AOM,
#
# NameError: name 'em' is not defined

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
nb = em.SVMMatcher(name='NaiveBayes', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')

# %%
# Generate a set of features
F = em.get_features_for_matching(WHED, AOM)

em.add_blackbox_feature(F, 'is_same_server', custom_matcher.is_same_server)
em.add_blackbox_feature(F, 'is_same_single_server', custom_matcher.is_same_single_server)

# F.feature_name
# Out:
# True

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='gold_label',
                            show_progress=False)

# %%
# Check if the feature vectors contain missing values
# A return value of True means that there are missing values
any(pd.notnull(H))
# Out:
# True

# %%
# Impute feature vectors with the mean of the column values.
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
                strategy='mean')

# %%
# Select the best ML matcher using CV
# Precision Score
result = em.select_matcher([dt, rf, svm, nb, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
        k=5,
        target_attr='gold_label', metric='precision', random_state=0)
result['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3    NaiveBayes
# 4        LinReg
# 5        LogReg
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x11009ab70>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x11009a4a8>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009aa20>
# 3        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009ae48>
# 4  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x10f65d4e0>
# 5  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x11009a128>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4  Fold 5  Mean score
# 0          5  0.882353  0.769231  0.941176  0.933333    0.85    0.875219
# 1          5  1.000000  0.909091  0.947368  0.882353    1.00    0.947762
# 2          5  0.846154  1.000000  0.933333  1.000000    1.00    0.955897
# 3          5  0.846154  1.000000  0.933333  1.000000    1.00    0.955897
# 4          5  1.000000  0.727273  0.900000  1.000000    1.00    0.925455
# 5          5  0.933333  0.769231  0.894737  0.933333    0.90    0.886127

# %%
# Recall Score
result = em.select_matcher([dt, rf, svm, nb, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
        k=5,
        target_attr='gold_label', metric='recall', random_state=0)
result['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3    NaiveBayes
# 4        LinReg
# 5        LogReg
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x11009ab70>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x11009a4a8>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009aa20>
# 3        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009ae48>
# 4  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x10f65d4e0>
# 5  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x11009a128>
#
#    Num folds  Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.9375  0.909091  0.888889  0.823529  0.809524    0.873707
# 1          5  0.8750  0.909091  1.000000  0.882353  0.809524    0.895194
# 2          5  0.6875  0.363636  0.777778  0.529412  0.190476    0.509760
# 3          5  0.6875  0.363636  0.777778  0.529412  0.190476    0.509760
# 4          5  0.8750  0.727273  1.000000  0.764706  0.857143    0.844824
# 5          5  0.8750  0.909091  0.944444  0.823529  0.857143    0.881842

# %%
# F1 Score
result = em.select_matcher([dt, rf, svm, nb, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
        k=5,
        target_attr='gold_label', metric='f1', random_state=0)
result['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3    NaiveBayes
# 4        LinReg
# 5        LogReg
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x11009ab70>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x11009a4a8>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009aa20>
# 3        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x11009ae48>
# 4  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x10f65d4e0>
# 5  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x11009a128>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.909091  0.833333  0.914286  0.875000  0.829268    0.872196
# 1          5  0.933333  0.909091  0.972973  0.882353  0.894737    0.918497
# 2          5  0.758621  0.533333  0.848485  0.692308  0.320000    0.630549
# 3          5  0.758621  0.533333  0.848485  0.692308  0.320000    0.630549
# 4          5  0.933333  0.727273  0.947368  0.866667  0.923077    0.879544
# 5          5  0.903226  0.833333  0.918919  0.875000  0.878049    0.881705

# %%
# Convert the J into a set of feature vectors using F
K = em.extract_feature_vecs(J, 
                            feature_table=F, 
                            attrs_after='gold_label',
                            show_progress=False)  
K = em.impute_table(K, 
                exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
                strategy='mean')

# %%
# Choose Random Forest to train
rf.fit(table=H, exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'], target_attr='gold_label')
predictions = rf.predict(table=K, exclude_attrs=['_id', 'ltable_' + csv_headers.WHED_INDEX, 'rtable_' + csv_headers.AOM_INDEX, 'gold_label'],
                append=True, target_attr='predicted', inplace=False)

eval_summary = em.eval_matches(predictions, 'gold_label', 'predicted')
em.print_eval_summary(eval_summary)
# Out:
# Precision : 98.63% (72/73)
# Recall : 91.14% (72/79)
# F1 : 94.74%
# False positives : 1 (out of 73 positive predictions)
# False negatives : 7 (out of 166 negative predictions)
