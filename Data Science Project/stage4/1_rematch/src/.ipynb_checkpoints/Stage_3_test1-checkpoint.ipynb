# %%
import sys
import os
import py_entitymatching as em
print('magellan version:' + em.__version__)
import re
import csv
import pandas as pd

from cleaner import Cleaner
from constants import csv_headers
# Out:
# magellan version:0.1.0

# %%
working_dir = os.path.dirname(os.getcwd())
path_to_csv_dir = working_dir + os.sep + 'csv_files'+ os.sep

# %% [markdown]
# # STEP 1 - PRE-PROCESSING DATA
#
# In this stage, we need to preprocess data before applying Megellan. This is because our datasets (especially the AOM dataset) are quite dirty, and therefore adversely affecting Megellan's blocking and matching functions. For example, states can take any value of "CA", "California", or "CA - California".
#
# In this step, we will clean the following variables:
# * Country name (e.g. Whed data has 2 Belgiums: (1) Belgium - French Community and (2) Belgium - Flemish Community)
# * State name
# * City name
# * Affiliation name
# * Email server domain (we will only capture the university information from the email server domain - if there is any)

# %% [markdown]
# ### 1.A. Clean AOM data

# %%
aom_cleaner = Cleaner(path_to_csv_dir + '_aom.csv', csv_headers.AOM_INDEX, csv_headers.AOM)

aom_cleaner.clean_affiliation('a_name')
aom_cleaner.clean_email_server('a_email_server')
aom_cleaner.clean_city('a_city')
aom_cleaner.clean_country('a_country')
aom_cleaner.clean_states('a_prov', 'a_country')

aom_cleaner.to_csv(path_to_csv_dir + '_aom_cleaned.csv')
aom_cleaner.data.head(n=3)
# Out:
#                           a_name            a_city         a_prov  \
# person_id
# 1             academy management  briarcliff manor       new york
# 4          nor astern university            boston  massachusetts
# 5               skidmore college  saratoga springs       new york
#
#                a_country a_email_server
# person_id
# 1          united states            aom
# 4          united states          gmail
# 5          united states       skidmore

# %%
rtuple = aom_cleaner.data.xs(59256)
rtuple
from constants import domains
print(domains.COUNTRY)
# Out:
# ['ac', 'ad', 'ae', 'af', 'ag', 'ai', 'al', 'am', 'an', 'ap', 'aq', 'ar', 'as', 'at', 'au', 'az', 'ba', 'bb', 'be', 'bf', 'bg', 'bh', 'bi', 'bm', 'bn', 'bo', 'br', 'bt', 'by', 'bz', 'ca', 'cc', 'cd', 'cf', 'cg', 'ch', 'ck', 'cl', 'cm', 'cn', 'co', 'cr', 'cu', 'cx', 'cy', 'cz', 'de', 'dj', 'dk', 'do', 'dz', 'ec', 'ee', 'eg', 'es', 'fi', 'fj', 'fk', 'fm', 'fr', 'fo', 'gb', 'ge', 'gf', 'gg', 'gh', 'gi', 'gl', 'gm', 'gn', 'gr', 'gs', 'gt', 'gu', 'hk', 'hm', 'hn', 'hr', 'hu', 'id', 'ie', 'il', 'im', 'in', 'int', 'io', 'ir', 'is', 'it', 'je', 'jo', 'jp', 'ke', 'kg', 'kh', 'kr', 'kw', 'ky', 'kz', 'lb', 'lc', 'li', 'lk', 'lr', 'lt', 'lu', 'lv', 'ly', 'mc', 'md', 'mg', 'mh', 'mk', 'mm', 'mn', 'mo', 'mp', 'mq', 'mr', 'ms', 'mt', 'mu', 'mx', 'my', 'mw', 'na', 'nc', 'nf', 'ni', 'nl', 'no', 'np', 'nu', 'nz', 'om', 'pa', 'pe', 'pg', 'ph', 'pk', 'qa', 're', 'ro', 'ru', 'rw', 'sa', 'sb', 'se', 'sg', 'sh', 'si', 'sk', 'sm', 'sn', 'so', 'st', 'su', 'sv', 'sz', 'tc', 'td', 'tf', 'th', 'tj', 'tm', 'tn', 'to', 'tp', 'tr', 'tt', 'tv', 'tw', 'tz', 'ua', 'ug', 'uk', 'um', 'us', 'uy', 'uz', 've', 'vg', 'vi', 'vu', 'wf', 'ws', 'yt', 'yu', 'za', 'zm']

# %% [raw]
# ### 1.B. Clean WHED data

# %%
whed_cleaner = Cleaner(path_to_csv_dir + '_whed.csv', csv_headers.WHED_INDEX, csv_headers.WHED, encoding = 'ISO-8859-1')

whed_cleaner.clean_affiliation('a_name')
whed_cleaner.clean_city('a_city')
whed_cleaner.clean_country('a_country')
whed_cleaner.clean_states('a_prov', 'a_country')

whed_cleaner.to_csv(path_to_csv_dir + '_whed_cleaned.csv')
whed_cleaner.data.head(n=3)
# Out:
#                                                 a_name    a_country  \
# a_id
# 2               pampanga state agricultural university  philippines
# 4     les roches international school hotel management  switzerland
# 6             dharma gate budapest buddhist university      hungary
#
#                     a_city                a_prov                     a_web
# a_id
# 2                 magalang              pampanga     http://www.pac.edu.ph
# 4     bluche crans montana  bluche-crans-montana  http://www.lesroches.edu
# 6                 budapest                              http://www.tkbf.eu

# %% [markdown]
# # STEP 2 - MAGELLAN - BLOCKING

# %%
AOM = em.read_csv_metadata(path_to_csv_dir + '_aom_cleaned.csv', key = csv_headers.AOM_INDEX)
print(em.get_key(AOM))

WHED = em.read_csv_metadata(path_to_csv_dir + '_whed_cleaned.csv', key = csv_headers.WHED_INDEX)
print(em.get_key(WHED))
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# person_id
# a_id

# %%
# building inverted index based on B
sample_WHED, sample_AOM = em.down_sample(WHED, AOM, size=3000, y_param=10)
print(len(sample_WHED))
print(len(sample_AOM))
em.show_properties(sample_WHED)
em.show_properties(sample_AOM)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:00:18 | ETA: 00:00:20 | ETA: 00:00:19 | ETA: 00:00:18 | ETA: 00:00:18 | ETA: 00:00:17 | ETA: 00:00:17 | ETA: 00:00:16 | ETA: 00:00:16 | ETA: 00:00:15 | ETA: 00:00:15 | ETA: 00:00:14 | ETA: 00:00:13 | ETA: 00:00:13 | ETA: 00:00:12 | ETA: 00:00:11 | ETA: 00:00:10 | ETA: 00:00:09 | ETA: 00:00:09 | ETA: 00:00:08 | ETA: 00:00:07 | ETA: 00:00:06 | ETA: 00:00:05 | ETA: 00:00:04 | ETA: 00:00:04 | ETA: 00:00:03 | ETA: 00:00:02 | ETA: 00:00:01 | ETA: 00:00:00 | ETA: 00:00:00 | ETA: 00:00:00
# 11177
# 3000
# id: 4752893656
# key: a_id
# id: 4752895000
# key: person_id
# Total time elapsed: 00:00:24

# %%
sample_WHED.head(n=5)
# Out:
#    a_id                                            a_name      a_country  \
# 1     4  les roches international school hotel management    switzerland
# 2     6          dharma gate budapest buddhist university        hungary
# 3     7                  a. d. patel institute technology          india
# 4     8                             a.t. still university  united states
# 5     9                                aalborg university        denmark
#
#                  a_city                a_prov                     a_web
# 1  bluche crans montana  bluche-crans-montana  http://www.lesroches.edu
# 2              budapest                   NaN        http://www.tkbf.eu
# 3    vitthal udyognagar               gujarat     http://www.adit.ac.in
# 4            kirksville              missouri       http://www.atsu.edu
# 5               aalborg                   NaN         http://www.aau.dk

# %%
sample_AOM.head(n=5)
# Out:
#       person_id                            a_name        a_city  \
# 5915      44473                         wu vienna        vienna
# 3514      24339      george washington university    washington
# 974        4554  sheldon b. lubar school business     milwaukee
# 3904      28014      erasmus university rotterdam     rotterdam
# 4076      29488             university st. gallen  sankt gallen
#
#                     a_prov      a_country a_email_server
# 5915                   NaN        austria             wu
# 3514  district of columbia  united states            gwu
# 974              wisconsin  united states            uwm
# 3904                   NaN    netherlands            rsm
# 4076                   NaN    switzerland          unisg

# %%
def match_country(ltuple, rtuple):
    l_country = ltuple['a_country']
    r_country = rtuple['a_country']
    if (l_country == "") or (r_country == ""):
        return None
    else:
        return ( l_country == r_country)

def match_country_us(ltuple, rtuple):
    return (rtuple['a_country'] == "united states")

def match_prov(ltuple, rtuple):
    l_prov = ltuple['a_prov']
    r_prov = rtuple['a_prov']
    if (l_prov == "") or (r_prov == ""):
        return None
    else:
        return (l_prov == r_prov)

def match_city(ltuple, rtuple):
    l_city = ltuple['a_city']
    r_city = rtuple['a_city']
    if (l_city  == "") or (r_city == ""):
        return None
    else:
        return (l_city == r_city)

def match_provcity(ltuple, rtuple):
    l_city = ltuple['a_city']
    r_city = rtuple['a_city']
    l_prov = ltuple['a_prov']
    r_prov = rtuple['a_prov']
    if (l_city  == "") or (r_city == "") or (l_prov == "") or (r_prov == ""):
        return None
    else:
        return (str(l_city) == str(r_prov)) or (str(l_prov) == str(r_city))

def match_domain(ltuple, rtuple):
    l_web = str(ltuple['a_web'])
    r_email = str(rtuple['a_email_server'])
    if (l_web == "") or (r_email == ""):
        return None
    else:
        l_web = l_web.split('.')
        return (r_email in l_web)

def match_overlap(ltuple, rtuple):
    l_name = str(ltuple['a_name'])
    r_name = str(rtuple['a_name'])
    
    if (l_name == "") or (r_name == ""):
        return None
    else:
        if l_name.count(" ") > 0 and r_name.count(" ") > 0:
            l_name = re.sub(r"(university|school|institute|college)","",l_name)
            r_name = re.sub(r"(university|school|institute|college)","",r_name)    
            l_tokens = em.tok_wspace(l_name)
            r_tokens = em.tok_wspace(r_name)
            return em.overlap_coeff(l_tokens, r_tokens) > 0.5
        else:
            return None
    
def allFalse(array):
    num_none = array.count(None)
    num_false = array.count(False)    
    return (num_none + num_false) == len(array) and num_none != len(array)
        
    
def match_combined(ltuple, rtuple):
    if match_country(ltuple, rtuple) is False:
        return True
    elif (match_country_us(ltuple,rtuple) is True) and (match_prov(ltuple,rtuple) is False):
        return True
    elif (match_country_us(ltuple,rtuple) is True) and (allFalse([match_overlap(ltuple, rtuple), 
                                                                   match_domain(ltuple, rtuple)]) is True):
        return True
    elif (match_country_us(ltuple,rtuple) is False) and allFalse([match_overlap(ltuple, rtuple), 
                                                                   match_domain(ltuple, rtuple)]) is True:
        return True
    else:
        return False
    
def blocking(A, B):
    bb = em.BlackBoxBlocker()
    bb.set_black_box_function(match_combined)
    C = bb.block_tables(A, B, l_output_attrs=['a_name','a_country','a_city','a_prov','a_web'], r_output_attrs=['a_name','a_country','a_city','a_prov','a_email_server'] )
    return C

C = blocking(sample_WHED, sample_AOM)
# Out:
# 0%                          100%
# [##############################] | ETA: 00:14:17 | ETA: 00:14:53 | ETA: 00:13:58 | ETA: 00:13:56 | ETA: 00:13:13 | ETA: 00:12:33 | ETA: 00:11:57 | ETA: 00:11:30 | ETA: 00:11:00 | ETA: 00:10:19 | ETA: 00:09:41 | ETA: 00:09:10 | ETA: 00:08:40 | ETA: 00:08:10 | ETA: 00:07:40 | ETA: 00:07:13 | ETA: 00:06:43 | ETA: 00:06:12 | ETA: 00:05:44 | ETA: 00:12:03 | ETA: 00:10:55 | ETA: 00:09:33 | ETA: 00:08:10 | ETA: 00:06:52 | ETA: 00:05:38 | ETA: 00:04:26 | ETA: 00:03:16 | ETA: 00:02:08 | ETA: 00:01:03 | ETA: 00:00:00 | ETA: 00:00:00
# Total time elapsed: 00:31:04

# %%
C.size
# Out:
# 388570

# %%
C.head(n=1000)
# Out:
#      _id  ltable_a_id  rtable_person_id  \
# 0      0            7             57798
# 1      1           10             17806
# 2      2           10             54466
# 3      3           10             58872
# 4      4           10              1239
# 5      5           10             15158
# 6      6           10             58547
# 7      7           10             50927
# 8      8           10             59274
# 9      9           10             54470
# 10    10           10             29248
# 11    11           10             48739
# 12    12           10             43727
# 13    13           10              9489
# 14    14           10             36477
# 15    15           10             49629
# 16    16           10             54387
# 17    17           15             28818
# 18    18           15             19726
# 19    19           15             33460
# 20    20           26              5231
# 21    21           27             24009
# 22    22           33             59256
# 23    23           33             29001
# 24    24           76              2488
# 25    25           78             34399
# 26    26           78             50593
# 27    27           78             58597
# 28    28           91             59256
# 29    29           91             29001
# ..   ...          ...               ...
# 970  970         1895             59127
# 971  971         1895             26304
# 972  972         1895             14945
# 973  973         1896             38673
# 974  974         1896              8606
# 975  975         1896             59142
# 976  976         1896             33097
# 977  977         1896             19955
# 978  978         1896             32345
# 979  979         1896              1291
# 980  980         1896              5296
# 981  981         1896              8770
# 982  982         1896             31362
# 983  983         1896              1218
# 984  984         1896             46065
# 985  985         1896             30609
# 986  986         1896             10131
# 987  987         1896              9112
# 988  988         1896             13569
# 989  989         1896             46520
# 990  990         1896             53247
# 991  991         1896             13629
# 992  992         1896             46080
# 993  993         1896             58355
# 994  994         1896             32352
# 995  995         1896             58466
# 996  996         1896              6910
# 997  997         1896             34635
# 998  998         1896             46073
# 999  999         1896             43080
#
#                                        ltable_a_name ltable_a_country  \
# 0                   a. d. patel institute technology            india
# 1                                   aalto university          finland
# 2                                   aalto university          finland
# 3                                   aalto university          finland
# 4                                   aalto university          finland
# 5                                   aalto university          finland
# 6                                   aalto university          finland
# 7                                   aalto university          finland
# 8                                   aalto university          finland
# 9                                   aalto university          finland
# 10                                  aalto university          finland
# 11                                  aalto university          finland
# 12                                  aalto university          finland
# 0              india      new delhi           NaN                  iitd
# 1            finland          espoo           NaN                 aalto
# 2            finland       helsinki           NaN                 aalto
# 3            finland       helsinki           NaN                 aalto
# 4            finland       helsinki           NaN                 aalto
# 5            finland          espoo         aalto                 aalto
# 6            finland          aalto           NaN                 aalto
# 7            finland       helsinki           NaN                 aalto
# 8            finland          aalto           NaN                 aalto
# 9            finland       helsinki           NaN                 aalto
# 10           finland          aalto             -                 aalto
# 11           finland       helsinki       uusimaa                 aalto
# 12           finland       helsinki      helsinki                 aalto
# 13           finland       helsinki           NaN                 aalto
# 14           finland          espoo           NaN                 aalto
# 15           finland          aalto           NaN                 aalto
# 16           finland       helsinki      helsinki                 aalto
# 17           denmark         aarhus       denmark                   asb
# 18           denmark         aarhus           NaN                   asb
# 19           denmark         aarhus           NaN                   asb
# 20     united states     fort worth         texas                   tcu
# 21           finland            abo           NaN                   abo
# 22           nigeria         bauchi           NaN                    ng
# 23           nigeria          lagos         lagos                    ng
# 24            canada      wolfville            ns               acadiau
# 25           germany        leipzig           NaN                   mpg
# 26           germany         erding           NaN            googlemail
# 27           germany       iserlohn           NaN         bits-iserlohn
# 28           nigeria         bauchi           NaN                    ng
# 29           nigeria          lagos         lagos                    ng
# ..               ...            ...           ...                   ...
# 970    united states       la jolla    california                  ucsd
# 971    united states    los angeles    california                  ucla
# 972    united states       berkeley    california              berkeley
# 973    united states    los angeles    california                   usc
# 974    united states      fullerton    california             fullerton
# 975    united states       berkeley    california              berkeley
# 976    united states    los angeles    california                   usc
# 977    united states    los angeles    california                   usc
# 978    united states   santa monica    california                   usc
# 979    united states      fullerton    california             fullerton
# 980    united states     sacramento    california                  csus
# 981    united states          davis    california               ucdavis
# 982    united states    los angeles    california                  ucla
# 983    united states       berkeley    california              berkeley
# 984    united states    los angeles    california                   usc
# 985    united states         moraga    california            stmarys-ca
# 986    united states     san marcos    california                 csusm
# 987    united states         irvine    california                   uci
# 988    united states  santa barbara    california                  ucsb
# 989    united states    los angeles    california                   usc
# 990    united states       berkeley    california              berkeley
# 991    united states     samta cruz    california                  ucsc
# 992    united states    los angeles    california                   usc
# 993    united states    los angeles    california                   usc
# 994    united states       berkeley    california                 gmail
# 995    united states       berkeley    california              berkeley
# 996    united states       berkeley    california              berkeley
# 997    united states    los angeles    california                   usc
# 998    united states    los angeles    california                   usc
# 999    united states       pasadena    california                 gmail
#
# [1000 rows x 13 columns]

# %%
rtuple = aom_cleaner.data.xs(59256)
rtuple
# Out:
# a_name            abubakar tafawa balewa university
# a_city                                       bauchi
# a_prov
# a_country                                   nigeria
# a_email_server                                   ng
# Name: 59256, dtype: object

# %%
ltuple = whed_cleaner.data.xs(676)
ltuple
# Out:
# a_name       academy fine arts vienna
# a_country                     austria
# a_city                           wien
# a_prov                         vienna
# a_web         http://www.akbild.ac.at
# Name: 676, dtype: object

# %%
l_tokens = ['a.','d.','patel','technology']
r_tokens = ['indian','technology','delhi']
em.overlap_coeff(l_tokens, r_tokens)
# Out:
# 0.3333333333333333
